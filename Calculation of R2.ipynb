# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = (21.0, 11.0)

# Reading Data with correct encoding.
data = pd.read_csv(r'C:\Users\maxnd\Documents\Machine Learning\car_purchasing.csv',  encoding='latin-1')
print(data.shape)
data.head()
# Out:
# (500, 9)
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
import pandas as pd

# Creating a sample DataFrame
data = {
    'Head Size(cm^3)': [1, 2, 3, 4, 5],
    'Brain Weight(grams)': [100, 200, 300, 400, 500]
}

df = pd.DataFrame(data)  # Correct capitalization

# Collecting X and Y
X = df['Head Size(cm^3)'].values
Y = df['Brain Weight(grams)'].values

# %%
# Getting mean value of x and y

mean_x = np.mean(X)
mean_y = np.mean(Y)

# Total number of values
n = len(X)

# Using formula to calculate b1 and b0
number = 0
denom = 0
for i in range(n):
    number += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = number / denom    
b0 = mean_y - (b1 * mean_x)

# Print coefficients
print(b1, b0)
# Out:
# 100.0 0.0

# %%
# making linear regresion in graphical form

import matplotlib.pyplot as plt

# Assuming the previois code for calculating b0, b1 and defining X, Y is already executed
# Finding out the max value and min values

max_x = np.max(X) + 100
min_x = np.min(X) - 100

# Calculating line values x and y
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x

# Plotting Line with regression line

plt.plot(x, y, c='#58b970', label='Regression Line')

# Plotting Scatter Points
plt.scatter(X, Y, c='#ef5423', label='Scatte Plot')

plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()

# %%
# sst equation
# ssr equation
# sse equation

# %%
ss_t = 0
ss_r = 0
for i in range(n):
    y_pred = b0 + b1 * X[i]
    ss_t += (Y[i] - mean_y) ** 2
    ss_r += (Y[i] - y_pred) ** 2

r2 = 1 - (ss_r/ss_t)
print(r2)
# Out:
# 1.0

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Reshaping X
X = X.reshape((n, 1))

# Creating Model
reg = LinearRegression()

# Fitting training data
reg = reg.fit(X, Y)

# Y Prediction
Y_pred = reg.predict(X)

# Calculating R2 Score
#r2_score = r2_score(Y, Y_pred)

r2_score = r2_score(Y, X_pred)

print(r2_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 19
#      14 Y_pred = reg.predict(X)
#      16 # Calculating R2 Score
#      17 #r2_score = r2_score(Y, Y_pred)
# ---> 19 r2_score = r2_score(Y, X_pred)
#      21 print(r2_score)
#
# NameError: name 'X_pred' is not defined
